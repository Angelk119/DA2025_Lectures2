# %%
import seaborn as sns
import pandas as pd

# %%
df = pd.DataFrame({
    'Department': ['Sales', 'Eng', 'HR', 'Sales', 'Eng', 'HR'],
    'Satisfaction': [4.1, 3.8, 4.3, 4.0, 3.7, 4.4]



})
sns.boxplot(x='Department', y= 'Satisfaction', data=df)
# Out:
# <Axes: xlabel='Department', ylabel='Satisfaction'>
